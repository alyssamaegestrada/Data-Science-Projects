# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

# %%
np.random.seed(10)

x = np.linspace(1,30,30)
y = np.random.randint(1,60,30)

y - y.cumsum()

iris = pd.read_csv('https://raw.githubusercontent.com/renatomaaliw3/public_files/master/Data%20Sets/iris.csv')

# %%
iris=pd.DataFrame(iris)
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0       0.0
# ...

# %%
#1. Draw a line Graph with figsize (10, 6), using x and y variables with custom maker, linestyle and linewidth (3), markersize (8)

# Plotting the line graph
plt.figure(figsize=(10, 6))
plt.plot(x, y, marker='o', color = 'black', linestyle='--', linewidth=3, markersize=8)

# Adding labels and title
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Line Graph using MatPlotLib')

# Display the plot
plt.grid(True)
plt.show()

# %%
#2. Draw a Scatter Graph with figsize (10,6)
sns.relplot(x="horsepower", y="", hue="origin", size="weight",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data= econ )

# %%
#3. Draw a Scatter Graph with figsize (10, 6) , with c = iris['target']

plt.figure(figsize=(10, 6))
iris = pd.read_csv('https://raw.githubusercontent.com/renatomaaliw3/public_files/master/Data%20Sets/iris.csv')
x = iris['sepal length (cm)']
y = iris['petal length (cm)']
c = iris['target']

plt.scatter(Iris['sepal length (cm)'], Iris['petal length (cm)'], marker='o', label='Scatter Plot', c = Iris['target'])

# Adding labels and title
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.title('Scatter Graph using MatPlotLib')

# Adding a colorbar for target values

# Display the plot
plt.grid(True)
plt.show()

# %%
#4. Create the following subplots (Subplot 1 is same as Number 1)

#1st Graph
# Plotting the line graph
plt.figure(figsize=(12, 5))

plt.suptitle('Subplotting in MatplotLib')
plt.subplot(1,2,1)
plt.plot(x, y, marker='o', color = 'black', linestyle='--', linewidth=3, markersize=8)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Line Graph using MatPlotLib')
plt.grid(True)

plt.legend()

#2nd Graph
plt.subplot(1, 2,2)
iris = ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
values = [5.1, 3.5, 1.4, 0.20]
# Create a bar graph with customizations
plt.bar(iris, values, color='red', linewidth=2, alpha=0.9, width=0.8) #barh --> height
plt.title('Subplot - 2')
plt.grid(alpha = 0.5)
plt.ylabel('In Centimeter', fontsize=8)

plt.tight_layout()
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 5. Nested Plots

# x-axis

x = np.linspace(1,21,20)
x

np.random.seed(10)

y = np.random.randint(1,50,20)
y
y = y.cumsum()

# %%
# Generate sample data for the main graph

# Create the main graph
plt.figure(figsize=(16, 8))

# Main graph

plt.plot(x, y, color='red', linestyle='-', linewidth=2)
plt.title('Main Graph')
plt.xlabel('X-axis', fontsize=12)
plt.ylabel('Y-axis', fontsize=12)
plt.grid(False)
plt.legend()

# Secondary Graph
left, bottom, width, height = [0.20, 0.63, 0.30, 0.18]
ax_inset = plt.axes([left, bottom, width, height])
ax_inset.plot(x, y, color='green', linestyle='-', linewidth=1)
ax_inset.set_title('Secondary Graph')
ax_inset.set_xlabel('X-axis', fontsize=8)
ax_inset.set_ylabel('Y-axis', fontsize=8)
ax_inset.grid(False)
ax_inset.legend()

#Tertiary Graph
left, bottom, width, height = [0.57, 0.19, 0.30, 0.18]
ax_inset = plt.axes([left, bottom, width, height])
ax_inset.plot(x, y, color='green', linestyle='-', linewidth=1)
ax_inset.set_title('Tertiary Graph')
ax_inset.set_xlabel('X-axis', fontsize=8)
ax_inset.set_ylabel('Y-axis', fontsize=8)
ax_inset.grid(False)
ax_inset.legend()

# Show the plot
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#6. Pie Chart

labels = ['Category A', 'Category B', 'Category C', 'Category D']
sizes = [25, 30, 20, 25]
colors = ['skyblue', 'lightgreen', 'lightcoral', 'yellow']

# Create a pie chart with customizations
plt.pie(sizes, labels = labels, colors = colors, explode = (0.1, 0.2, 0.3, 0.3), autopct='%1.1f%%', shadow = True, startangle=65,
        textprops = {'color': 'black', 'fontsize': 12, 'fontweight': 'bold'}, pctdistance = 0.50, labeldistance = 1.2)
#Customize the plot
plt.title('Customize Pie Chart' , pad = 15)
plt.show()
