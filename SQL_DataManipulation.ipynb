# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %%
#Load Dataset

nba = pd.read_csv('https://raw.githubusercontent.com/renatomaaliw3/public_files/master/Data%20Sets/nba.csv')
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
#Check for missing data
nba.isnull().sum()
# Out:
# Name          1
# Team          1
# Position      8
# Height        7
# Weight        8
# College      14
# Salary      104
# dtype: int64

# %%
#Remove data with all column values of'Nan'

nba = nba.dropna(how = 'all')
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
#Replace Salary with NaN with 0
nba['Salary'].fillna(0, inplace = True)
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
#Replace College with Nan with unknown

nba['College'].fillna('Unknown', inplace = True)
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
#Show actual rows with missing data

nba[nba.isnull().any(axis = 1)]
# Out:
#                 Name              Team Position Height  Weight  College  \
# 15      Miles Norris     Atlanta Hawks      NaN    NaN     NaN  Unknown
# 129    Jordan Walker  Dallas Mavericks      NaN    NaN     NaN  Unknown
# 134      Souley Boum    Denver Nuggets      NaN    NaN     NaN  Unknown
# 138  Armaan Franklin    Denver Nuggets      NaN    NaN     NaN  Unknown
# 299    Caleb Daniels        Miami Heat      NaN    NaN     NaN  Unknown
# 460   Toumani Camara      Phoenix Suns        F    6-8     NaN   Dayton
# 541     Kevin Obanor   Toronto Raptors      NaN    6-8   235.0  Unknown
# 564     Nick Ongenda         Utah Jazz      NaN    NaN     NaN  Unknown
#
#         Salary
# 15    559782.0
# 129  1119563.0
# 134  1119563.0
# 138  1119563.0
# 299  1119563.0
# 460  1119563.0
# 541  1119563.0
# 564  1119563.0

# %%
#Remove all data with Nan

nba.dropna(inplace = True)
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
#as type, Salary, Weight data type to int

nba['Salary'] = nba['Salary'].astype('int')
nba['Weight'] = nba['Weight'].astype('int')
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7     215
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5     225
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5     195
# 3         Clint Capela       Atlanta Hawks        C   6-10     256
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10     240
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4     194
# 587       Ryan Rollins  Washington Wizards        G    6-3     180
# 588      Landry Shamet  Washington Wizards        G    6-4     190
# 589   Tristan Vukcevic  Washington Wizards        F   6-10     220
# 590       Delon Wright  Washington Wizards        G    6-5     185
#
#            College    Salary
# 0        Villanova   4556983
# 1       Fenerbahce  18700000
# 2         Michigan   4094244
# 3      Elan Chalon  20616000
# ...

# %%
#Reset Index

nba.reset_index(drop = True, inplace = True)
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7     215
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5     225
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5     195
# 3         Clint Capela       Atlanta Hawks        C   6-10     256
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10     240
# ..                 ...                 ...      ...    ...     ...
# 578       Jordan Poole  Washington Wizards        G    6-4     194
# 579       Ryan Rollins  Washington Wizards        G    6-3     180
# 580      Landry Shamet  Washington Wizards        G    6-4     190
# 581   Tristan Vukcevic  Washington Wizards        F   6-10     220
# 582       Delon Wright  Washington Wizards        G    6-5     185
#
#            College    Salary
# 0        Villanova   4556983
# 1       Fenerbahce  18700000
# 2         Michigan   4094244
# 3      Elan Chalon  20616000
# ...

# %%
import sqlite3
conn = sqlite3.connect(':memory')

# %%
nba.to_sql('NBA', conn, index = False)
# Out:
# 583

# %%
query = "SELECT * FROM NBA"
result_sql = pd.read_sql_query(query,conn)
result_sql
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7     215
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5     225
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5     195
# 3         Clint Capela       Atlanta Hawks        C   6-10     256
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10     240
# ..                 ...                 ...      ...    ...     ...
# 578       Jordan Poole  Washington Wizards        G    6-4     194
# 579       Ryan Rollins  Washington Wizards        G    6-3     180
# 580      Landry Shamet  Washington Wizards        G    6-4     190
# 581   Tristan Vukcevic  Washington Wizards        F   6-10     220
# 582       Delon Wright  Washington Wizards        G    6-5     185
#
#            College    Salary
# 0        Villanova   4556983
# 1       Fenerbahce  18700000
# 2         Michigan   4094244
# 3      Elan Chalon  20616000
# ...

# %%
#1. What is the average AVG() salary for the Team of 'New York Knicks'

#Execute a SQL Query

query = "SELECT Team, AVG(Salary) AS 'Average Salary of NYK' FROM NBA GROUP BY Team HAVING Team = 'New York Knicks' "
result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#               Team  Average Salary of NYK
# 0  New York Knicks           7.903559e+06

# %%
#2. Who are the top 5 highest paid player on the Miami Heat Team? You can use the keyword LIMIT 5 after the ORDER BY

query = "SELECT Name,Salary FROM NBA WHERE Team = 'Miami Heat'ORDER BY Salary DESC LIMIT 5 "
result_sql = pd.read_sql_query(query, conn)
result_sql
# Out:
#               Name    Salary
# 0     Jimmy Butler  45183960
# 1      Bam Adebayo  32600060
# 2       Kyle Lowry  29682540
# 3      Tyler Herro  27000000
# 4  Duncan Robinson  18154000

# %%
#3. Who are the highest paid player for each team in the NBA, sort by Salary Descending? You can use Max(Salary) then GROUP BY

query = "SELECT Name, Team, MAX(Salary) AS 'Highest Paid' FROM NBA GROUP BY Team ORDER BY Salary DESC"
result_sql = pd.read_sql_query(query,conn)
result_sql
# Out:
#                        Name                    Team  Highest Paid
# 0             Stephen Curry   Golden State Warriors      51915615
# 1              Kevin Durant            Phoenix Suns      47649433
# 2               Joel Embiid      Philadelphia 76ers      47607350
# 3              LeBron James      Los Angeles Lakers      47607350
# 4              Nikola Jokic          Denver Nuggets      47607350
# 5            Damian Lillard  Portland Trail Blazers      45640084
# 6     Giannis Antetokounmpo         Milwaukee Bucks      45640084
# 7               Paul George    Los Angeles Clippers      45640084
# 8              Jimmy Butler              Miami Heat      45183960
# 9               Rudy Gobert  Minnesota Timberwolves      41000000
# 10            Fred VanVleet         Houston Rockets      40806300
# 11              Luka Doncic        Dallas Mavericks      40064220
# 12              Zach LaVine           Chicago Bulls      40064220
# ...

# %%
#4. How many players are part of each Team, ORDER BY 'Current Players' in DESCENDING?

query = "SELECT Team, COUNT(Name) AS 'Current Player' FROM NBA GROUP BY Team ORDER BY COUNT(Name) DESC "
result_sql = pd.read_sql_query(query,conn)
result_sql
# Out:
#                       Team  Current Player
# 0          Milwaukee Bucks              22
# 1        Memphis Grizzlies              22
# 2         Dallas Mavericks              22
# 3       Washington Wizards              21
# 4       Philadelphia 76ers              21
# 5    Oklahoma City Thunder              21
# 6          New York Knicks              21
# 7               Miami Heat              21
# 8           Indiana Pacers              21
# 9                Utah Jazz              20
# 10         Toronto Raptors              20
# 11       San Antonio Spurs              20
# 12         Houston Rockets              20
# 13          Denver Nuggets              20
# 14       Charlotte Hornets              20
# 15            Phoenix Suns              19
# 16  Minnesota Timberwolves              19
# 17      Los Angeles Lakers              19
# 18    Los Angeles Clippers              19
# 19         Detroit Pistons              19
# 20     Cleveland Cavaliers              19
# ...

# %%
#5. Who are the players that have salaries between 10M to 25M in the Houston Rockets or Dallas Mavericks, in Salary descending order, Name in ascending order?

query = "SELECT * FROM NBA WHERE (Team = 'Houston Rockets' OR Team = 'Dallas Mavericks') AND Salary BETWEEN 10000000 AND 25000000 ORDER BY Salary DESC, Name ASC;  "
result_sql = pd.read_sql_query(query,conn)
result_sql
# Out:
#              Name              Team Position Height  Weight        College  \
# 0   Dillon Brooks   Houston Rockets      G-F    6-6     225         Oregon
# 1  Grant Williams  Dallas Mavericks        F    6-6     236      Tennessee
# 2  Richaun Holmes  Dallas Mavericks        F    6-8     235  Bowling Green
# 3     Maxi Kleber  Dallas Mavericks        F   6-10     240  Bayern Munich
#
#      Salary
# 0  22627671
# 1  12405000
# 2  12046020
# 3  11000000

# %%
#6. Show me the highest and lowest paid amount of Salary in the Phoenix Suns roster?

query = "SELECT MAX(Salary) AS 'Highest Salary', MIN(Salary) AS 'Lowest Salary' from NBA WHERE Team = 'Phoenix Suns' "
result_sql = pd.read_sql_query(query,conn)
result_sql
# Out:
#    Highest Salary  Lowest Salary
# 0        47649433              0

# %%
#7. The General Manager is looking for any (Forward), it does not matter if he is playing two positions, with weight of 185 lbs to 220 lbs. above, with current salary of 20M to 30M

query = "SELECT * FROM NBA WHERE Position LIKE '%F%' AND Salary BETWEEN 20000000 AND 30000000 AND Weight BETWEEN 185 AND 220"
result_sql = pd.read_sql_query(query,conn)
result_sql
# Out:
#               Name                    Team Position Height  Weight  \
# 0    Mikal Bridges           Brooklyn Nets      G-F    6-6     209
# 1  Cameron Johnson           Brooklyn Nets        F    6-8     210
# 2    DeMar DeRozan           Chicago Bulls      G-F    6-6     220
# 3   Andrew Wiggins   Golden State Warriors        F    6-7     197
# 4      Bruce Brown          Indiana Pacers      G-F    6-4     202
# 5       RJ Barrett         New York Knicks      F-G    6-6     214
# 6     Jerami Grant  Portland Trail Blazers        F    6-8     210
# 7   Keldon Johnson       San Antonio Spurs      F-G    6-5     220
#
#                College    Salary
# 0            Villanova  21700000
# 1       North Carolina  25679348
# 2  Southern California  28600000
# 3               Kansas  24330357
# 4                Miami  22000000
# 5                 Duke  23883929
# 6             Syracuse  27586207
# 7             Kentucky  20000000

# %%
#8. Who are the players who entered the league from High School and has a salary of 30M and above, ORDER BY Name

query = "SELECT * FROM NBA WHERE College LIKE '%HS%' AND Salary >=30000000 ORDER BY Name DESC"
result_sql = pd.read_sql_query(query,conn)
result_sql
# Out:
#            Name                Team Position Height  Weight  \
# 0  LeBron James  Los Angeles Lakers        F    6-9     250
#
#                         College    Salary
# 0  St. Vincent-St. Mary HS (OH)  47607350

# %%
#9. The team is looking for a pure Center (C) with height of at least 7 feet tall, Salary of 18M and above ,  with weight of 250 and above
#Salary in descending ORDER

query = "SELECT * FROM NBA WHERE Position LIKE 'C' AND Height >= 7 AND Salary >= 18000000 AND Weight >= 250 ORDER BY Name DESC "
result_sql = pd.read_sql_query(query,conn)
result_sql
# Out:
#             Name                    Team Position Height  Weight   College  \
# 0    Rudy Gobert  Minnesota Timberwolves        C    7-1     258    Cholet
# 1  Deandre Ayton            Phoenix Suns        C    7-0     250   Arizona
# 2    Brook Lopez         Milwaukee Bucks        C    7-1     282  Stanford
#
#      Salary
# 0  41000000
# 1  32459438
# 2  25000000

# %%
#10. Give me players that plays two positions from the Brooklyn Nets of New York Knicks, sort by Salary Descending and Weight Descending

query = "SELECT * FROM NBA WHERE Position LIKE '%-%' AND (Team = 'Brooklyn Nets' OR Team = 'New York Knicks')  ORDER BY Salary DESC, Weight DESC"
result_sql = pd.read_sql_query(query,conn)
result_sql
# Out:
#                   Name             Team Position Height  Weight  \
# 0          Ben Simmons    Brooklyn Nets      G-F   6-10     240
# 1        Julius Randle  New York Knicks      F-C    6-8     250
# 2           RJ Barrett  New York Knicks      F-G    6-6     214
# 3        Mikal Bridges    Brooklyn Nets      G-F    6-6     209
# 4        Evan Fournier  New York Knicks      G-F    6-6     205
# 5    Mitchell Robinson  New York Knicks      C-F    7-0     240
# 6   Isaiah Hartenstein  New York Knicks      C-F    7-0     250
# 7      DaQuan Jeffries  New York Knicks      G-F    6-5     222
# 8        Nathan Knight  New York Knicks      F-C    6-8     253
# 9        Dylan Windler  New York Knicks      G-F    6-7     196
# 10    Lonnie Walker IV    Brooklyn Nets      G-F    6-4     204
#
#                College    Salary
# 0      Louisiana State  37893408
# 1             Kentucky  28226880
# 2                 Duke  23883929
# 3            Villanova  21700000
# ...

# %%
#11. What are the teams in NBA that has an average Salary of 9M and above?

query = "SELECT Team, AVG(Salary) AS 'Average Salary' FROM NBA GROUP BY Team HAVING AVG(Salary)>=9000000 ORDER BY AVG(Salary) DESC"
result_sql = pd.read_sql_query(query,conn)
result_sql
# Out:
#                       Team  Average Salary
# 0     New Orleans Pelicans    1.498415e+07
# 1    Golden State Warriors    1.497651e+07
# 2           Boston Celtics    1.186472e+07
# 3             Phoenix Suns    1.169536e+07
# 4     Los Angeles Clippers    1.162476e+07
# 5   Portland Trail Blazers    1.130454e+07
# 6   Minnesota Timberwolves    1.125923e+07
# 7          Milwaukee Bucks    1.095304e+07
# 8       Philadelphia 76ers    1.090689e+07
# 9         Dallas Mavericks    1.045465e+07
# 10           Brooklyn Nets    1.034799e+07
# 11      Los Angeles Lakers    1.034555e+07
# 12     Cleveland Cavaliers    1.026259e+07
# 13           Chicago Bulls    9.801939e+06
# 14              Miami Heat    9.213828e+06
